# %%
# !pwd
# Out:
# /home/sanju/mycode/Part-based-3D-Reconstruction

# %%
# !git add .

# %%
# !git config --global user.name "Barnita Sharma"
# !git config --global user.email "barnitasharma@gmail.com"

# %%
# !git config --global --list
# Out:
# user.name=Barnita Sharma
# user.email=barnitasharma@gmail.com

# %%
# !git commit -m "Initial commit: Part-based 3D reconstruction pipeline"
# Out:
# [master (root-commit) 971d2db] Initial commit: Part-based 3D reconstruction pipeline
#  74 files changed, 3696493 insertions(+)
#  create mode 100644 .ipynb_checkpoints/1.Orthographic semantic voxel carving-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/2.Perspective camera estimation-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/3.Part-wise 3D refinement-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/4. Intra-method analysis-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/5. Inter-method analysis-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 1.Orthographic semantic voxel carving.ipynb
#  create mode 100644 2.Perspective camera estimation.ipynb
#  create mode 100644 3.Part-wise 3D refinement.ipynb
#  create mode 100644 4. Intra-method analysis.ipynb
#  create mode 100644 5. Inter-method analysis.ipynb
#  create mode 100644 Untitled.ipynb
# ...

# %%
# !git remote add origin https://github.com/BarnitaSharma/Part-based-3D-Reconstruction.git

# %%
# !git remote -v
# Out:
# origin	https://github.com/BarnitaSharma/Part-based-3D-Reconstruction.git (fetch)
# origin	https://github.com/BarnitaSharma/Part-based-3D-Reconstruction.git (push)

# %%
# !git push -u origin main
# Out:
# Username for 'https://github.com': ^C
